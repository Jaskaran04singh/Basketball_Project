# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Icz1dQsdcPYsghbX8HLm")
project = rf.workspace("fyp-3bwmg").project("reloc2-den7l")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# Running cells with 'basketball_env (Python 3.13.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Jaskaran Singh/OneDrive/Documents/Desktop/basketball project/basketball_env/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
from ultralytics import YOLO

# Load a pretrained pose estimation model (yolov8x-pose.pt is the extra-large variant for better accuracy)
model = YOLO("yolov8x-pose.pt")

# Train the model
model.train(
    data="reloc2-1/data.yaml",  # Path to your dataset config
    epochs=100,                 # Number of epochs
    imgsz=640,                  # Image size for training
    batch=16,                   # Batch size (adjust based on your GPU memory)
    optimizer='AdamW',          # Optimizer (AdamW is stable and effective)
                    # Enable mixed precision for faster training and lower memory usage
)
