# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Icz1dQsdcPYsghbX8HLm")
project = rf.workspace("workspace-5ujvu").project("basketball-players-fy4c2-vfsuv")
version = project.version(17)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Basketball-Players-17 to yolov8:: 100%|██████████| 23029/23029 [00:33<00:00, 689.60it/s]
# Extracting Dataset Version Zip to Basketball-Players-17 in yolov8:: 100%|██████████| 652/652 [00:00<00:00, 1033.69it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")  

model.train(
    data="Basketball-Players-17/data.yaml",
    epochs=250,
    imgsz=640,           

    optimizer='AdamW',  
)
